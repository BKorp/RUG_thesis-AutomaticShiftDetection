# %% [markdown]
# # imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from helpers.threshold_tester import ContextualThres, StaticThres, SyntaxThres
import pandas as pd
from sklearn.metrics import classification_report
from collections import defaultdict
import numpy as np

# %% [markdown]
# # static

# %%
static_unsupervised = pd.read_csv('../data/2_new_run/15072023_180241-mapped_unsupervised-static.tsv', sep='\t', index_col=0)
static_unsup_ident = pd.read_csv('../data/2_new_run/15072023_181327-mapped_unsup_ident-static.tsv', sep='\t', index_col=0)
static_semi_sup = pd.read_csv('../data/2_new_run/15072023_182411-mapped_semi_supervised-static.tsv', sep='\t', index_col=0)

# %%
static_gold = pd.read_csv('../data/2_new_run/static_gold.tsv', sep='\t', index_col=0)
static_gold
# Out:
#      film  sent_idx          src           tgt    label_static
# 0    AC01         0    delivered  overgedragen    Reproduction
# 1    AC01         1          his          zijn    Reproduction
# 2    AC01         5        swear        zweert    Reproduction
# 3    AC01         8            I           Dat  Creative Shift
# 4    AC01        37          Sit            Ga  Creative Shift
# ..    ...       ...          ...           ...             ...
# 120  DR02       331         Poor         Armen    Reproduction
# 121  DR02       335        gotta        moeten    Reproduction
# 122  DR02       389    worthless          niks  Creative Shift
# 123  DR01       979        share          deel    Reproduction
# 124  DR02       401  Considering        Gezien    Reproduction
#
# [125 rows x 5 columns]

# %%
def static_pred_creator(gold:pd.DataFrame, df:pd.DataFrame):
    pred = pd.DataFrame()
    for idx, i in gold.iterrows():
        pred = pd.concat([pred, df[
            (df.film == i.film) 
            & (df.sent_idx == i.sent_idx) 
            & (df.src == i.src) 
            & (df.tgt == i.tgt)].copy()
        ])
    return pred

# %% [markdown]
# ## Unsupervised FastText

# %%
unsup_pred = static_pred_creator(static_gold, static_unsupervised)

# %%
# Some sentences contain the same words twice, such as 'be tough , be tough ,' 
# which leads to duplicate word pairs, they are removed as I do not take 
# them into consideration with the gold data.
display(unsup_pred[unsup_pred.duplicated()])
unsup_pred.drop_duplicates(inplace=True)
# Out:
#         film            genre  sent_idx  \
# 89889   CH04  children_family       615
# 230838  CO10           comedy       602
# 324226  DO10      documentary       306
#
#                                                  src_sent  \
# 89889                               be tough , be tough ,
# 230838  Yeah , you 're good . It 's okay . That 's okay .
# 324226                                      Sure . Sure .
#
#                                               tgt_sent    src         tgt  \
# 89889                                   wees dan sterk  tough       sterk
# 230838  Niks aan de hand . Helemaal niks aan de hand .   okay        hand
# 324226                                    Natuurlijk .   Sure  Natuurlijk
#
#         static_cosine   type
# 89889        0.466335  human
# 230838       0.677257  human
# 324226       0.290294  human

# %%
unsup_pred
# Out:
#         film   genre  sent_idx  \
# 3       AC01  action         0
# 12      AC01  action         1
# 37      AC01  action         5
# 55      AC01  action         8
# 203     AC01  action        37
# ...      ...     ...       ...
# 344090  DR02   drama       331
# 344127  DR02   drama       335
# 344410  DR02   drama       389
# 340115  DR01   drama       979
# 344477  DR02   drama       401
#
#                                                  src_sent  \
# 3       The Inquisition has finally delivered Spain to...
# 12      Sultan Muhammad and his people still hold out ...
# 37      swear to honor our Order in the fight for free...
# 55                                              I swear .
# 203                Sit down . You 're making me nervous .
# ...                                                   ...
# 344090              Poor men fighting a rich man 's war .
# 344127    Point is , us old soldiers gotta live , right ?
# 344410                 No , no . No , this is worthless .
# 340115              I gave Bubba 's mama Bubba 's share .
# 344477  Considering what you did to my associate over ...
#
#                                                  tgt_sent          src  \
# 3       Andalusië , Spanje , 1492 De Inquisitie heeft ...    delivered
# 12      Sultan Mohammed en zijn mensen zitten nog in G...          his
# 37                         zweert gij trouw aan de Orde ?        swear
# 55                                         Dat zweer ik .            I
# 203                      Ga zitten . U maakt me nerveus .          Sit
# ...                                                   ...          ...
# 344090                 Armen die vochten voor de rijken .         Poor
# 344127            Wij oud-soldaten moeten ook rondkomen .        gotta
# 344410                             Hier heb je niks aan .    worthless
# 340115                gaf ik Bubba's deel aan zijn mama .        share
# 344477      Gezien wat je mijn compagnon hebt aangedaan .  Considering
#
#                  tgt  static_cosine   type
# 3       overgedragen       0.475222  human
# 12              zijn       0.440071  human
# 37            zweert       0.535506  human
# 55               Dat       0.614092  human
# 203               Ga       0.636277  human
# ...              ...            ...    ...
# 344090         Armen       0.742416  human
# 344127        moeten       0.483638  human
# 344410          niks       0.506961  human
# 340115          deel       0.557937  human
# 344477        Gezien       0.173222  human
#
# [125 rows x 9 columns]

# %%
statf_u = StaticThres(gold_data=static_gold)
statf_u(unsup_pred)
statf_u.score()
# Out:
#       precision    recall  f1-score  support t_metric
# 0.40   0.627234  0.614912  0.431418    125.0    basic
# 0.45   0.651259  0.672807  0.518490    125.0    basic
# 0.50   0.666667  0.728070  0.634975    125.0    basic
# 0.55   0.580882  0.596491  0.583333    125.0    basic
# 0.60   0.613324  0.586842  0.593556    125.0    basic

# %%
statf_u.get_best()
# Out:
#      precision   recall  f1-score  support t_metric
# 0.5   0.666667  0.72807  0.634975    125.0    basic

# %% [markdown]
# ## Unsupervised Identical Word FastText

# %%
unsup_ident_pred = static_pred_creator(static_gold, static_unsup_ident)

# %%
# Some sentences contain the same words twice, such as 'be tough , be tough ,' 
# which leads to duplicate word pairs, they are removed as I do not take 
# them into consideration with the gold data.
display(unsup_ident_pred[unsup_ident_pred.duplicated()])
unsup_ident_pred.drop_duplicates(inplace=True)
# Out:
#         film            genre  sent_idx  \
# 89889   CH04  children_family       615
# 230838  CO10           comedy       602
# 324226  DO10      documentary       306
#
#                                                  src_sent  \
# 89889                               be tough , be tough ,
# 230838  Yeah , you 're good . It 's okay . That 's okay .
# 324226                                      Sure . Sure .
#
#                                               tgt_sent    src         tgt  \
# 89889                                   wees dan sterk  tough       sterk
# 230838  Niks aan de hand . Helemaal niks aan de hand .   okay        hand
# 324226                                    Natuurlijk .   Sure  Natuurlijk
#
#         static_cosine   type
# 89889        0.465088  human
# 230838       0.679262  human
# 324226       0.292931  human

# %%
unsup_ident_pred
# Out:
#         film   genre  sent_idx  \
# 3       AC01  action         0
# 12      AC01  action         1
# 37      AC01  action         5
# 55      AC01  action         8
# 203     AC01  action        37
# ...      ...     ...       ...
# 344090  DR02   drama       331
# 344127  DR02   drama       335
# 344410  DR02   drama       389
# 340115  DR01   drama       979
# 344477  DR02   drama       401
#
#                                                  src_sent  \
# 3       The Inquisition has finally delivered Spain to...
# 12      Sultan Muhammad and his people still hold out ...
# 37      swear to honor our Order in the fight for free...
# 55                                              I swear .
# 203                Sit down . You 're making me nervous .
# ...                                                   ...
# 344090              Poor men fighting a rich man 's war .
# 344127    Point is , us old soldiers gotta live , right ?
# 344410                 No , no . No , this is worthless .
# 340115              I gave Bubba 's mama Bubba 's share .
# 344477  Considering what you did to my associate over ...
#
#                                                  tgt_sent          src  \
# 3       Andalusië , Spanje , 1492 De Inquisitie heeft ...    delivered
# 12      Sultan Mohammed en zijn mensen zitten nog in G...          his
# 37                         zweert gij trouw aan de Orde ?        swear
# 55                                         Dat zweer ik .            I
# 203                      Ga zitten . U maakt me nerveus .          Sit
# ...                                                   ...          ...
# 344090                 Armen die vochten voor de rijken .         Poor
# 344127            Wij oud-soldaten moeten ook rondkomen .        gotta
# 344410                             Hier heb je niks aan .    worthless
# 340115                gaf ik Bubba's deel aan zijn mama .        share
# 344477      Gezien wat je mijn compagnon hebt aangedaan .  Considering
#
#                  tgt  static_cosine   type
# 3       overgedragen       0.474148  human
# 12              zijn       0.440958  human
# 37            zweert       0.532376  human
# 55               Dat       0.611416  human
# 203               Ga       0.639054  human
# ...              ...            ...    ...
# 344090         Armen       0.749895  human
# 344127        moeten       0.480705  human
# 344410          niks       0.506652  human
# 340115          deel       0.559434  human
# 344477        Gezien       0.173017  human
#
# [125 rows x 9 columns]

# %%
statf_i = StaticThres(gold_data=static_gold)
statf_i(unsup_ident_pred)
statf_i.score()
# Out:
#       precision    recall  f1-score  support t_metric
# 0.40   0.629441  0.620175  0.439677    125.0    basic
# 0.45   0.655784  0.683333  0.533582    125.0    basic
# 0.50   0.666667  0.728070  0.634975    125.0    basic
# 0.55   0.580882  0.596491  0.583333    125.0    basic
# 0.60   0.602604  0.581579  0.587218    125.0    basic

# %%
statf_i.get_best()
# Out:
#      precision   recall  f1-score  support t_metric
# 0.5   0.666667  0.72807  0.634975    125.0    basic

# %% [markdown]
# ## Semi-supervised FastText

# %%
semi_sup_pred = static_pred_creator(static_gold, static_semi_sup)

# %%
# Some sentences contain the same words twice, such as 'be tough , be tough ,' 
# which leads to duplicate word pairs, they are removed as I do not take 
# them into consideration with the gold data.
display(semi_sup_pred[semi_sup_pred.duplicated()])
semi_sup_pred.drop_duplicates(inplace=True)
# Out:
#         film            genre  sent_idx  \
# 89889   CH04  children_family       615
# 230838  CO10           comedy       602
# 324226  DO10      documentary       306
#
#                                                  src_sent  \
# 89889                               be tough , be tough ,
# 230838  Yeah , you 're good . It 's okay . That 's okay .
# 324226                                      Sure . Sure .
#
#                                               tgt_sent    src         tgt  \
# 89889                                   wees dan sterk  tough       sterk
# 230838  Niks aan de hand . Helemaal niks aan de hand .   okay        hand
# 324226                                    Natuurlijk .   Sure  Natuurlijk
#
#         static_cosine   type
# 89889        0.464757  human
# 230838       0.679424  human
# 324226       0.291758  human

# %%
semi_sup_pred
# Out:
#         film   genre  sent_idx  \
# 3       AC01  action         0
# 12      AC01  action         1
# 37      AC01  action         5
# 55      AC01  action         8
# 203     AC01  action        37
# ...      ...     ...       ...
# 344090  DR02   drama       331
# 344127  DR02   drama       335
# 344410  DR02   drama       389
# 340115  DR01   drama       979
# 344477  DR02   drama       401
#
#                                                  src_sent  \
# 3       The Inquisition has finally delivered Spain to...
# 12      Sultan Muhammad and his people still hold out ...
# 37      swear to honor our Order in the fight for free...
# 55                                              I swear .
# 203                Sit down . You 're making me nervous .
# ...                                                   ...
# 344090              Poor men fighting a rich man 's war .
# 344127    Point is , us old soldiers gotta live , right ?
# 344410                 No , no . No , this is worthless .
# 340115              I gave Bubba 's mama Bubba 's share .
# 344477  Considering what you did to my associate over ...
#
#                                                  tgt_sent          src  \
# 3       Andalusië , Spanje , 1492 De Inquisitie heeft ...    delivered
# 12      Sultan Mohammed en zijn mensen zitten nog in G...          his
# 37                         zweert gij trouw aan de Orde ?        swear
# 55                                         Dat zweer ik .            I
# 203                      Ga zitten . U maakt me nerveus .          Sit
# ...                                                   ...          ...
# 344090                 Armen die vochten voor de rijken .         Poor
# 344127            Wij oud-soldaten moeten ook rondkomen .        gotta
# 344410                             Hier heb je niks aan .    worthless
# 340115                gaf ik Bubba's deel aan zijn mama .        share
# 344477      Gezien wat je mijn compagnon hebt aangedaan .  Considering
#
#                  tgt  static_cosine   type
# 3       overgedragen       0.474036  human
# 12              zijn       0.442340  human
# 37            zweert       0.534009  human
# 55               Dat       0.615675  human
# 203               Ga       0.640848  human
# ...              ...            ...    ...
# 344090         Armen       0.745218  human
# 344127        moeten       0.479617  human
# 344410          niks       0.507071  human
# 340115          deel       0.560364  human
# 344477        Gezien       0.172302  human
#
# [125 rows x 9 columns]

# %%
statf_s = StaticThres(gold_data=static_gold)
statf_s(semi_sup_pred)
statf_s.score()
# Out:
#       precision    recall  f1-score  support t_metric
# 0.40   0.629441  0.620175  0.439677    125.0    basic
# 0.45   0.655784  0.683333  0.533582    125.0    basic
# 0.50   0.666667  0.728070  0.634975    125.0    basic
# 0.55   0.580882  0.596491  0.583333    125.0    basic
# 0.60   0.602604  0.581579  0.587218    125.0    basic

# %%
statf_s.get_best()
# Out:
#      precision   recall  f1-score  support t_metric
# 0.5   0.666667  0.72807  0.634975    125.0    basic

# %% [markdown]
# ## F-scores for original gold data scores from van der Heden

# %%
orig_data = pd.read_csv('../data/heden_samples_en_v2.tsv', sep='\t')
orig_scores = defaultdict(list)
for i in [.4, .45, .5, .55, .6]:
    orig_scores['thres'].append(i)
    orig_data[i] = ['Creative Shift' if row.score > i else 'Reproduction' for idx, row in orig_data.iterrows()]

    print(f'Threshold {i} classification report:')
    print(classification_report(orig_data['class'], orig_data[i], zero_division=0.0, output_dict=False))
    print('')

    for key, value in classification_report(orig_data['class'], orig_data[i], output_dict=True, zero_division=0.0)['macro avg'].items():
        orig_scores[key].append(value)

orig_scores_df = pd.DataFrame.from_dict(orig_scores).set_index('thres').style.highlight_max(subset=['f1-score'], color = 'lightgreen', axis = 0)
display(orig_scores_df)
# Out:
# Threshold 0.4 classification report:
#                 precision    recall  f1-score   support
#
# Creative Shift       0.31      1.00      0.48        39
#   Reproduction       0.00      0.00      0.00        86
#
#       accuracy                           0.31       125
#      macro avg       0.16      0.50      0.24       125
#   weighted avg       0.10      0.31      0.15       125
#
#
# Threshold 0.45 classification report:
#                 precision    recall  f1-score   support
#
# Creative Shift       0.37      0.92      0.53        39
#   Reproduction       0.89      0.28      0.42        86
#
#       accuracy                           0.48       125
#      macro avg       0.63      0.60      0.48       125
#   weighted avg       0.73      0.48      0.46       125
#
#
# Threshold 0.5 classification report:
#                 precision    recall  f1-score   support
#
# Creative Shift       0.42      0.67      0.51        39
#   Reproduction       0.79      0.58      0.67        86
#
#       accuracy                           0.61       125
#      macro avg       0.61      0.62      0.59       125
#   weighted avg       0.68      0.61      0.62       125
#
#
# Threshold 0.55 classification report:
#                 precision    recall  f1-score   support
#
# Creative Shift       0.39      0.36      0.37        39
#   Reproduction       0.72      0.74      0.73        86
#
#       accuracy                           0.62       125
#      macro avg       0.55      0.55      0.55       125
#   weighted avg       0.62      0.62      0.62       125
#
#
# Threshold 0.6 classification report:
#                 precision    recall  f1-score   support
#
# Creative Shift       0.00      0.00      0.00        39
#   Reproduction       0.69      1.00      0.82        86
#
#       accuracy                           0.69       125
#      macro avg       0.34      0.50      0.41       125
#   weighted avg       0.47      0.69      0.56       125
# <style type="text/css">
# #T_f9ac2_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9ac2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9ac2_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_f9ac2_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_f9ac2_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_f9ac2_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >thres</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9ac2_level0_row0" class="row_heading level0 row0" >0.400000</th>
#       <td id="T_f9ac2_row0_col0" class="data row0 col0" >0.156000</td>
#       <td id="T_f9ac2_row0_col1" class="data row0 col1" >0.500000</td>
#       <td id="T_f9ac2_row0_col2" class="data row0 col2" >0.237805</td>
#       <td id="T_f9ac2_row0_col3" class="data row0 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row1" class="row_heading level0 row1" >0.450000</th>
#       <td id="T_f9ac2_row1_col0" class="data row1 col0" >0.628118</td>
#       <td id="T_f9ac2_row1_col1" class="data row1 col1" >0.601073</td>
#       <td id="T_f9ac2_row1_col2" class="data row1 col2" >0.475163</td>
#       <td id="T_f9ac2_row1_col3" class="data row1 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row2" class="row_heading level0 row2" >0.500000</th>
#       <td id="T_f9ac2_row2_col0" class="data row2 col0" >0.606503</td>
#       <td id="T_f9ac2_row2_col1" class="data row2 col1" >0.624031</td>
#       <td id="T_f9ac2_row2_col2" class="data row2 col2" >0.592996</td>
#       <td id="T_f9ac2_row2_col3" class="data row2 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row3" class="row_heading level0 row3" >0.550000</th>
#       <td id="T_f9ac2_row3_col0" class="data row3 col0" >0.553995</td>
#       <td id="T_f9ac2_row3_col1" class="data row3 col1" >0.551580</td>
#       <td id="T_f9ac2_row3_col2" class="data row3 col2" >0.552381</td>
#       <td id="T_f9ac2_row3_col3" class="data row3 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row4" class="row_heading level0 row4" >0.600000</th>
#       <td id="T_f9ac2_row4_col0" class="data row4 col0" >0.344000</td>
#       <td id="T_f9ac2_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_f9ac2_row4_col2" class="data row4 col2" >0.407583</td>
#       <td id="T_f9ac2_row4_col3" class="data row4 col3" >125.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Overall scores

# %%
print('Macro avg scores for the original gold data from van der Heden')
display(orig_scores_df)
print('\nScores using the edited gold data:')
print('\nStatic unsupervised scores')
display(statf_u.comp_df.style.highlight_max(subset=['f1-score'], color = 'lightgreen', axis = 0))
print('\nStatic unsupervised identical scores')
display(statf_i.comp_df.style.highlight_max(subset=['f1-score'], color = 'lightgreen', axis = 0))
print('\nStatic semi-supervised scores')
display(statf_s.comp_df.style.highlight_max(subset=['f1-score'], color = 'lightgreen', axis = 0))
# Out:
# Macro avg scores for the original gold data from van der Heden
# <style type="text/css">
# #T_f9ac2_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f9ac2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9ac2_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_f9ac2_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_f9ac2_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_f9ac2_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >thres</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9ac2_level0_row0" class="row_heading level0 row0" >0.400000</th>
#       <td id="T_f9ac2_row0_col0" class="data row0 col0" >0.156000</td>
#       <td id="T_f9ac2_row0_col1" class="data row0 col1" >0.500000</td>
#       <td id="T_f9ac2_row0_col2" class="data row0 col2" >0.237805</td>
#       <td id="T_f9ac2_row0_col3" class="data row0 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row1" class="row_heading level0 row1" >0.450000</th>
#       <td id="T_f9ac2_row1_col0" class="data row1 col0" >0.628118</td>
#       <td id="T_f9ac2_row1_col1" class="data row1 col1" >0.601073</td>
#       <td id="T_f9ac2_row1_col2" class="data row1 col2" >0.475163</td>
#       <td id="T_f9ac2_row1_col3" class="data row1 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row2" class="row_heading level0 row2" >0.500000</th>
#       <td id="T_f9ac2_row2_col0" class="data row2 col0" >0.606503</td>
#       <td id="T_f9ac2_row2_col1" class="data row2 col1" >0.624031</td>
#       <td id="T_f9ac2_row2_col2" class="data row2 col2" >0.592996</td>
#       <td id="T_f9ac2_row2_col3" class="data row2 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row3" class="row_heading level0 row3" >0.550000</th>
#       <td id="T_f9ac2_row3_col0" class="data row3 col0" >0.553995</td>
#       <td id="T_f9ac2_row3_col1" class="data row3 col1" >0.551580</td>
#       <td id="T_f9ac2_row3_col2" class="data row3 col2" >0.552381</td>
#       <td id="T_f9ac2_row3_col3" class="data row3 col3" >125.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9ac2_level0_row4" class="row_heading level0 row4" >0.600000</th>
#       <td id="T_f9ac2_row4_col0" class="data row4 col0" >0.344000</td>
#       <td id="T_f9ac2_row4_col1" class="data row4 col1" >0.500000</td>
#       <td id="T_f9ac2_row4_col2" class="data row4 col2" >0.407583</td>
#       <td id="T_f9ac2_row4_col3" class="data row4 col3" >125.000000</td>
#     </tr>
#   </tbody>
# </table>
# Scores using the edited gold data:
#
# Static unsupervised scores
# <style type="text/css">
# #T_b99f5_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b99f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b99f5_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_b99f5_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_b99f5_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_b99f5_level0_col3" class="col_heading level0 col3" >support</th>
#       <th id="T_b99f5_level0_col4" class="col_heading level0 col4" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b99f5_level0_row0" class="row_heading level0 row0" >0.400000</th>
#       <td id="T_b99f5_row0_col0" class="data row0 col0" >0.627234</td>
#       <td id="T_b99f5_row0_col1" class="data row0 col1" >0.614912</td>
#       <td id="T_b99f5_row0_col2" class="data row0 col2" >0.431418</td>
#       <td id="T_b99f5_row0_col3" class="data row0 col3" >125.000000</td>
#       <td id="T_b99f5_row0_col4" class="data row0 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_b99f5_level0_row1" class="row_heading level0 row1" >0.450000</th>
#       <td id="T_b99f5_row1_col0" class="data row1 col0" >0.651259</td>
#       <td id="T_b99f5_row1_col1" class="data row1 col1" >0.672807</td>
#       <td id="T_b99f5_row1_col2" class="data row1 col2" >0.518490</td>
#       <td id="T_b99f5_row1_col3" class="data row1 col3" >125.000000</td>
#       <td id="T_b99f5_row1_col4" class="data row1 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_b99f5_level0_row2" class="row_heading level0 row2" >0.500000</th>
#       <td id="T_b99f5_row2_col0" class="data row2 col0" >0.666667</td>
#       <td id="T_b99f5_row2_col1" class="data row2 col1" >0.728070</td>
#       <td id="T_b99f5_row2_col2" class="data row2 col2" >0.634975</td>
#       <td id="T_b99f5_row2_col3" class="data row2 col3" >125.000000</td>
#       <td id="T_b99f5_row2_col4" class="data row2 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_b99f5_level0_row3" class="row_heading level0 row3" >0.550000</th>
#       <td id="T_b99f5_row3_col0" class="data row3 col0" >0.580882</td>
#       <td id="T_b99f5_row3_col1" class="data row3 col1" >0.596491</td>
#       <td id="T_b99f5_row3_col2" class="data row3 col2" >0.583333</td>
#       <td id="T_b99f5_row3_col3" class="data row3 col3" >125.000000</td>
#       <td id="T_b99f5_row3_col4" class="data row3 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_b99f5_level0_row4" class="row_heading level0 row4" >0.600000</th>
#       <td id="T_b99f5_row4_col0" class="data row4 col0" >0.613324</td>
#       <td id="T_b99f5_row4_col1" class="data row4 col1" >0.586842</td>
#       <td id="T_b99f5_row4_col2" class="data row4 col2" >0.593556</td>
#       <td id="T_b99f5_row4_col3" class="data row4 col3" >125.000000</td>
#       <td id="T_b99f5_row4_col4" class="data row4 col4" >basic</td>
#     </tr>
#   </tbody>
# </table>
# Static unsupervised identical scores
# <style type="text/css">
# #T_f96c5_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f96c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f96c5_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_f96c5_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_f96c5_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_f96c5_level0_col3" class="col_heading level0 col3" >support</th>
#       <th id="T_f96c5_level0_col4" class="col_heading level0 col4" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f96c5_level0_row0" class="row_heading level0 row0" >0.400000</th>
#       <td id="T_f96c5_row0_col0" class="data row0 col0" >0.629441</td>
#       <td id="T_f96c5_row0_col1" class="data row0 col1" >0.620175</td>
#       <td id="T_f96c5_row0_col2" class="data row0 col2" >0.439677</td>
#       <td id="T_f96c5_row0_col3" class="data row0 col3" >125.000000</td>
#       <td id="T_f96c5_row0_col4" class="data row0 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_f96c5_level0_row1" class="row_heading level0 row1" >0.450000</th>
#       <td id="T_f96c5_row1_col0" class="data row1 col0" >0.655784</td>
#       <td id="T_f96c5_row1_col1" class="data row1 col1" >0.683333</td>
#       <td id="T_f96c5_row1_col2" class="data row1 col2" >0.533582</td>
#       <td id="T_f96c5_row1_col3" class="data row1 col3" >125.000000</td>
#       <td id="T_f96c5_row1_col4" class="data row1 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_f96c5_level0_row2" class="row_heading level0 row2" >0.500000</th>
#       <td id="T_f96c5_row2_col0" class="data row2 col0" >0.666667</td>
#       <td id="T_f96c5_row2_col1" class="data row2 col1" >0.728070</td>
#       <td id="T_f96c5_row2_col2" class="data row2 col2" >0.634975</td>
#       <td id="T_f96c5_row2_col3" class="data row2 col3" >125.000000</td>
#       <td id="T_f96c5_row2_col4" class="data row2 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_f96c5_level0_row3" class="row_heading level0 row3" >0.550000</th>
#       <td id="T_f96c5_row3_col0" class="data row3 col0" >0.580882</td>
#       <td id="T_f96c5_row3_col1" class="data row3 col1" >0.596491</td>
#       <td id="T_f96c5_row3_col2" class="data row3 col2" >0.583333</td>
#       <td id="T_f96c5_row3_col3" class="data row3 col3" >125.000000</td>
#       <td id="T_f96c5_row3_col4" class="data row3 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_f96c5_level0_row4" class="row_heading level0 row4" >0.600000</th>
#       <td id="T_f96c5_row4_col0" class="data row4 col0" >0.602604</td>
#       <td id="T_f96c5_row4_col1" class="data row4 col1" >0.581579</td>
#       <td id="T_f96c5_row4_col2" class="data row4 col2" >0.587218</td>
#       <td id="T_f96c5_row4_col3" class="data row4 col3" >125.000000</td>
#       <td id="T_f96c5_row4_col4" class="data row4 col4" >basic</td>
#     </tr>
#   </tbody>
# </table>
# Static semi-supervised scores
# <style type="text/css">
# #T_fd4f8_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fd4f8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd4f8_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_fd4f8_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_fd4f8_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_fd4f8_level0_col3" class="col_heading level0 col3" >support</th>
#       <th id="T_fd4f8_level0_col4" class="col_heading level0 col4" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd4f8_level0_row0" class="row_heading level0 row0" >0.400000</th>
#       <td id="T_fd4f8_row0_col0" class="data row0 col0" >0.629441</td>
#       <td id="T_fd4f8_row0_col1" class="data row0 col1" >0.620175</td>
#       <td id="T_fd4f8_row0_col2" class="data row0 col2" >0.439677</td>
#       <td id="T_fd4f8_row0_col3" class="data row0 col3" >125.000000</td>
#       <td id="T_fd4f8_row0_col4" class="data row0 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_fd4f8_level0_row1" class="row_heading level0 row1" >0.450000</th>
#       <td id="T_fd4f8_row1_col0" class="data row1 col0" >0.655784</td>
#       <td id="T_fd4f8_row1_col1" class="data row1 col1" >0.683333</td>
#       <td id="T_fd4f8_row1_col2" class="data row1 col2" >0.533582</td>
#       <td id="T_fd4f8_row1_col3" class="data row1 col3" >125.000000</td>
#       <td id="T_fd4f8_row1_col4" class="data row1 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_fd4f8_level0_row2" class="row_heading level0 row2" >0.500000</th>
#       <td id="T_fd4f8_row2_col0" class="data row2 col0" >0.666667</td>
#       <td id="T_fd4f8_row2_col1" class="data row2 col1" >0.728070</td>
#       <td id="T_fd4f8_row2_col2" class="data row2 col2" >0.634975</td>
#       <td id="T_fd4f8_row2_col3" class="data row2 col3" >125.000000</td>
#       <td id="T_fd4f8_row2_col4" class="data row2 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_fd4f8_level0_row3" class="row_heading level0 row3" >0.550000</th>
#       <td id="T_fd4f8_row3_col0" class="data row3 col0" >0.580882</td>
#       <td id="T_fd4f8_row3_col1" class="data row3 col1" >0.596491</td>
#       <td id="T_fd4f8_row3_col2" class="data row3 col2" >0.583333</td>
#       <td id="T_fd4f8_row3_col3" class="data row3 col3" >125.000000</td>
#       <td id="T_fd4f8_row3_col4" class="data row3 col4" >basic</td>
#     </tr>
#     <tr>
#       <th id="T_fd4f8_level0_row4" class="row_heading level0 row4" >0.600000</th>
#       <td id="T_fd4f8_row4_col0" class="data row4 col0" >0.602604</td>
#       <td id="T_fd4f8_row4_col1" class="data row4 col1" >0.581579</td>
#       <td id="T_fd4f8_row4_col2" class="data row4 col2" >0.587218</td>
#       <td id="T_fd4f8_row4_col3" class="data row4 col3" >125.000000</td>
#       <td id="T_fd4f8_row4_col4" class="data row4 col4" >basic</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Looking at the overall scores, it is clear that the basic threshold with the best Macro Avg F1-score is 0.5 for both the original data and the edited gold data in all instances. The new scores are slightly higher, moving from 0.59 to 0.63. What can also be seen is that the scores for each of the Vecmap embeddings are slightly different, but overall almost the same, with the exact same f1-scores for the best threshold of 0.5.
#
# The choice for the best FastText processing is not as clear, as the f1-scores for the best threshold are the same.
#
# This leads me to conclude that none of the static embedding workflows are necessarily better than the others, leading to a baseline macro avg F1-score of 0.63 for testing.

# %%
statf_s.thres_dfs[0.5].to_csv('../results/static_semi_supervised_best_thres_gold.tsv', sep='\t')

# %%
static_semi_sup['static_labels'] = ['Creative Shift' if row.static_cosine > 0.5 else 'Reproduction' for idx, row in static_semi_sup.iterrows()]

# %%
best_thres_report = pd.DataFrame.from_dict(statf_s.thres_reports[0.5]).T
best_thres_report.loc['accuracy', 'precision'] = None
best_thres_report.loc['accuracy', 'recall'] = None
best_thres_report.loc['accuracy', 'support'] = best_thres_report.loc['macro avg', 'support']

# %%
best_thres_report.to_csv('../results/static_semi_supervised_best_thres_report.tsv', sep='\t')

# %%
statf_s.comp_df.to_csv('../results/static_semi_supervised_thresholds.tsv', sep='\t')
static_semi_sup.to_csv('../results/static_semi_supervised_data.tsv', sep='\t')

# %% [markdown]
# ## Machine conversion

# %%
machine_static_semi_sup = pd.read_csv('../data/2_new_run/16072023_174925-mapped_semi_supervised-static_mt.tsv', sep='\t', index_col=0)
machine_static_semi_sup['type'] = 'machine'
mt_static_conv = StaticThres(static_gold, thresholds=[0.5,])
mt_static_conv.cur_thres = 0.5
machine_static_semi_sup['static_labels'] = [mt_static_conv.static_thres(i.static_cosine) for idx, i in machine_static_semi_sup.iterrows()]
machine_static_semi_sup
# Out:
#         film   genre  sent_idx  \
# 0       AC01  action         0
# 1       AC01  action         0
# 2       AC01  action         0
# 3       AC01  action         0
# 4       AC01  action         0
# ...      ...     ...       ...
# 531523  DR10   drama       805
# 531524  DR10   drama       806
# 531525  DR10   drama       806
# 531526  DR10   drama       806
# 531527  DR10   drama       806
#
#                                                  src_sent  \
# 0       The Inquisition has finally delivered Spain to...
# 1       The Inquisition has finally delivered Spain to...
# 2       The Inquisition has finally delivered Spain to...
# 3       The Inquisition has finally delivered Spain to...
# 4       The Inquisition has finally delivered Spain to...
# ...                                                   ...
# 531523                        I guess it 's just us now .
# 531524                                          Just us ?
# 531525                                          Just us ?
# 531526                                          Just us ?
# 531527                                          Just us ?
#
#                                                  tgt_sent          src  \
# 0       De inquisitie heeft Spanje eindelijk uitgeleve...          The
# 1       De inquisitie heeft Spanje eindelijk uitgeleve...  Inquisition
# 2       De inquisitie heeft Spanje eindelijk uitgeleve...          has
# 3       De inquisitie heeft Spanje eindelijk uitgeleve...      finally
# 4       De inquisitie heeft Spanje eindelijk uitgeleve...    delivered
# ...                                                   ...          ...
# 531523                    Ik denk dat we nu alleen zijn .            .
# 531524                                       Alleen wij ?         Just
# 531525                                       Alleen wij ?           us
# 531526                                       Alleen wij ?           us
# 531527                                       Alleen wij ?            ?
#
#                 tgt  static_cosine     type   static_labels
# 0                De       0.435872  machine    Reproduction
# 1        inquisitie       0.301858  machine    Reproduction
# 2             heeft       0.126774  machine    Reproduction
# 3         eindelijk       0.128372  machine    Reproduction
# 4       uitgeleverd       0.455937  machine    Reproduction
# ...             ...            ...      ...             ...
# 531523            .       0.166176  machine    Reproduction
# 531524       Alleen       0.360403  machine    Reproduction
# 531525       Alleen       0.756379  machine  Creative Shift
# 531526          wij       0.441017  machine    Reproduction
# 531527            ?       0.132348  machine    Reproduction
#
# [531528 rows x 10 columns]

# %%
machine_static_semi_sup.to_csv('../results/machine_static_semi_supervised_data.tsv', sep='\t')

# %% [markdown]
# # Context

# %% [markdown]
# ## Human

# %%
context_hu = pd.read_csv('../data/2_new_run/12072023_171117-context.tsv', sep='\t', index_col=0)
contf = ContextualThres(gold_data='../data/context_gold_edits.tsv', human_label='label_context')
# contf = ContextualThres(gold_data='../data/context_gold_fixes.tsv', human_label='label_context')
contf(context_hu)

# %%
contf.score()

# %%
context_thres = contf.comp_df.reset_index(names='threshold')
context_thres.threshold = context_thres.threshold.map(lambda x: f'{x}')
context_thres.support = context_thres.support.map(lambda x: int(x))
display(context_thres.style.highlight_max(subset=['f1-score'], color = 'mediumseagreen', axis = 0).hide())
# Out:
# <style type="text/css">
# #T_0406d_row14_col3 {
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_0406d">
#   <thead>
#     <tr>
#       <th id="T_0406d_level0_col0" class="col_heading level0 col0" >threshold</th>
#       <th id="T_0406d_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_0406d_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_0406d_level0_col3" class="col_heading level0 col3" >f1-score</th>
#       <th id="T_0406d_level0_col4" class="col_heading level0 col4" >support</th>
#       <th id="T_0406d_level0_col5" class="col_heading level0 col5" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0406d_row0_col0" class="data row0 col0" >0.4</td>
#       <td id="T_0406d_row0_col1" class="data row0 col1" >0.583719</td>
#       <td id="T_0406d_row0_col2" class="data row0 col2" >0.620029</td>
#       <td id="T_0406d_row0_col3" class="data row0 col3" >0.539689</td>
#       <td id="T_0406d_row0_col4" class="data row0 col4" >125</td>
#       <td id="T_0406d_row0_col5" class="data row0 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row1_col0" class="data row1 col0" >0.4</td>
#       <td id="T_0406d_row1_col1" class="data row1 col1" >0.557051</td>
#       <td id="T_0406d_row1_col2" class="data row1 col2" >0.581922</td>
#       <td id="T_0406d_row1_col3" class="data row1 col3" >0.526515</td>
#       <td id="T_0406d_row1_col4" class="data row1 col4" >125</td>
#       <td id="T_0406d_row1_col5" class="data row1 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row2_col0" class="data row2 col0" >0.4</td>
#       <td id="T_0406d_row2_col1" class="data row2 col1" >0.583719</td>
#       <td id="T_0406d_row2_col2" class="data row2 col2" >0.620029</td>
#       <td id="T_0406d_row2_col3" class="data row2 col3" >0.539689</td>
#       <td id="T_0406d_row2_col4" class="data row2 col4" >125</td>
#       <td id="T_0406d_row2_col5" class="data row2 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row3_col0" class="data row3 col0" >0.45</td>
#       <td id="T_0406d_row3_col1" class="data row3 col1" >0.587179</td>
#       <td id="T_0406d_row3_col2" class="data row3 col2" >0.625184</td>
#       <td id="T_0406d_row3_col3" class="data row3 col3" >0.546264</td>
#       <td id="T_0406d_row3_col4" class="data row3 col4" >125</td>
#       <td id="T_0406d_row3_col5" class="data row3 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row4_col0" class="data row4 col0" >0.45</td>
#       <td id="T_0406d_row4_col1" class="data row4 col1" >0.555901</td>
#       <td id="T_0406d_row4_col2" class="data row4 col2" >0.579529</td>
#       <td id="T_0406d_row4_col3" class="data row4 col3" >0.533850</td>
#       <td id="T_0406d_row4_col4" class="data row4 col4" >125</td>
#       <td id="T_0406d_row4_col5" class="data row4 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row5_col0" class="data row5 col0" >0.45</td>
#       <td id="T_0406d_row5_col1" class="data row5 col1" >0.560734</td>
#       <td id="T_0406d_row5_col2" class="data row5 col2" >0.587077</td>
#       <td id="T_0406d_row5_col3" class="data row5 col3" >0.532826</td>
#       <td id="T_0406d_row5_col4" class="data row5 col4" >125</td>
#       <td id="T_0406d_row5_col5" class="data row5 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row6_col0" class="data row6 col0" >0.5</td>
#       <td id="T_0406d_row6_col1" class="data row6 col1" >0.590676</td>
#       <td id="T_0406d_row6_col2" class="data row6 col2" >0.630339</td>
#       <td id="T_0406d_row6_col3" class="data row6 col3" >0.552834</td>
#       <td id="T_0406d_row6_col4" class="data row6 col4" >125</td>
#       <td id="T_0406d_row6_col5" class="data row6 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row7_col0" class="data row7 col0" >0.5</td>
#       <td id="T_0406d_row7_col1" class="data row7 col1" >0.571834</td>
#       <td id="T_0406d_row7_col2" class="data row7 col2" >0.597754</td>
#       <td id="T_0406d_row7_col3" class="data row7 col3" >0.565185</td>
#       <td id="T_0406d_row7_col4" class="data row7 col4" >125</td>
#       <td id="T_0406d_row7_col5" class="data row7 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row8_col0" class="data row8 col0" >0.5</td>
#       <td id="T_0406d_row8_col1" class="data row8 col1" >0.592342</td>
#       <td id="T_0406d_row8_col2" class="data row8 col2" >0.628314</td>
#       <td id="T_0406d_row8_col3" class="data row8 col3" >0.583611</td>
#       <td id="T_0406d_row8_col4" class="data row8 col4" >125</td>
#       <td id="T_0406d_row8_col5" class="data row8 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row9_col0" class="data row9 col0" >0.55</td>
#       <td id="T_0406d_row9_col1" class="data row9 col1" >0.581797</td>
#       <td id="T_0406d_row9_col2" class="data row9 col2" >0.617636</td>
#       <td id="T_0406d_row9_col3" class="data row9 col3" >0.548611</td>
#       <td id="T_0406d_row9_col4" class="data row9 col4" >125</td>
#       <td id="T_0406d_row9_col5" class="data row9 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row10_col0" class="data row10 col0" >0.55</td>
#       <td id="T_0406d_row10_col1" class="data row10 col1" >0.568056</td>
#       <td id="T_0406d_row10_col2" class="data row10 col2" >0.590206</td>
#       <td id="T_0406d_row10_col3" class="data row10 col3" >0.564662</td>
#       <td id="T_0406d_row10_col4" class="data row10 col4" >125</td>
#       <td id="T_0406d_row10_col5" class="data row10 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row11_col0" class="data row11 col0" >0.55</td>
#       <td id="T_0406d_row11_col1" class="data row11 col1" >0.595150</td>
#       <td id="T_0406d_row11_col2" class="data row11 col2" >0.623527</td>
#       <td id="T_0406d_row11_col3" class="data row11 col3" >0.596742</td>
#       <td id="T_0406d_row11_col4" class="data row11 col4" >125</td>
#       <td id="T_0406d_row11_col5" class="data row11 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row12_col0" class="data row12 col0" >0.6</td>
#       <td id="T_0406d_row12_col1" class="data row12 col1" >0.564462</td>
#       <td id="T_0406d_row12_col2" class="data row12 col2" >0.592231</td>
#       <td id="T_0406d_row12_col3" class="data row12 col3" >0.539138</td>
#       <td id="T_0406d_row12_col4" class="data row12 col4" >125</td>
#       <td id="T_0406d_row12_col5" class="data row12 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row13_col0" class="data row13 col0" >0.6</td>
#       <td id="T_0406d_row13_col1" class="data row13 col1" >0.582329</td>
#       <td id="T_0406d_row13_col2" class="data row13 col2" >0.605670</td>
#       <td id="T_0406d_row13_col3" class="data row13 col3" >0.583333</td>
#       <td id="T_0406d_row13_col4" class="data row13 col4" >125</td>
#       <td id="T_0406d_row13_col5" class="data row13 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_0406d_row14_col0" class="data row14 col0" >0.6</td>
#       <td id="T_0406d_row14_col1" class="data row14 col1" >0.615793</td>
#       <td id="T_0406d_row14_col2" class="data row14 col2" >0.636598</td>
#       <td id="T_0406d_row14_col3" class="data row14 col3" >0.621976</td>
#       <td id="T_0406d_row14_col4" class="data row14 col4" >125</td>
#       <td id="T_0406d_row14_col5" class="data row14 col5" >basic</td>
#     </tr>
#   </tbody>
# </table>

# %%
contf.get_best()
# Out:
#      precision    recall  f1-score  support t_metric
# 0.6   0.615793  0.636598  0.621976    125.0    basic

# %%
best_thres_report = pd.DataFrame.from_dict(contf.thres_reports[contf.get_best().index[0]][contf.get_best().iloc[0].t_metric]).T
best_thres_report.loc['accuracy', 'precision'] = None
best_thres_report.loc['accuracy', 'recall'] = None
best_thres_report.loc['accuracy', 'support'] = best_thres_report.loc['macro avg', 'support']

# %%
best_thres_report
# Out:
#                 precision    recall  f1-score  support
# creative shift   0.388889  0.500000  0.437500     28.0
# reproduction     0.842697  0.773196  0.806452     97.0
# accuracy              NaN       NaN  0.712000    125.0
# macro avg        0.615793  0.636598  0.621976    125.0
# weighted avg     0.741044  0.712000  0.723806    125.0

# %%
contf.best_df().to_csv('../results/context_data.tsv', sep='\t')
best_thres_report.to_csv('../results/context_best_thres_report.tsv', sep='\t')
context_thres.to_csv('../results/context_thresholds.tsv', sep='\t')
contf.retrieve_best_gold().reset_index(names='orig_df_idx').to_csv('../results/context_best_thres_gold.tsv', sep='\t')

# %% [markdown]
# ## Machine

# %%
context_mt = pd.read_csv('../data/2_new_run/16072023_180924-context_mt.tsv', sep='\t', index_col=0)
contf_mt = ContextualThres(gold_data='../data/context_mt_gold_edited.tsv', human_label='label_context')
contf_mt(context_mt)

# %%
contf_mt.score()

# %%
context_thres_mt = contf_mt.comp_df.reset_index(names='threshold')
context_thres_mt.threshold = context_thres_mt.threshold.map(lambda x: f'{x}')
context_thres_mt.support = context_thres_mt.support.map(lambda x: int(x))
display(context_thres_mt.style.highlight_max(subset=['f1-score'], color = 'mediumseagreen', axis = 0).hide())
# Out:
# <style type="text/css">
# #T_8cb17_row8_col3 {
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_8cb17">
#   <thead>
#     <tr>
#       <th id="T_8cb17_level0_col0" class="col_heading level0 col0" >threshold</th>
#       <th id="T_8cb17_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_8cb17_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_8cb17_level0_col3" class="col_heading level0 col3" >f1-score</th>
#       <th id="T_8cb17_level0_col4" class="col_heading level0 col4" >support</th>
#       <th id="T_8cb17_level0_col5" class="col_heading level0 col5" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8cb17_row0_col0" class="data row0 col0" >0.4</td>
#       <td id="T_8cb17_row0_col1" class="data row0 col1" >0.597670</td>
#       <td id="T_8cb17_row0_col2" class="data row0 col2" >0.648213</td>
#       <td id="T_8cb17_row0_col3" class="data row0 col3" >0.561588</td>
#       <td id="T_8cb17_row0_col4" class="data row0 col4" >125</td>
#       <td id="T_8cb17_row0_col5" class="data row0 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row1_col0" class="data row1 col0" >0.4</td>
#       <td id="T_8cb17_row1_col1" class="data row1 col1" >0.566821</td>
#       <td id="T_8cb17_row1_col2" class="data row1 col2" >0.600622</td>
#       <td id="T_8cb17_row1_col3" class="data row1 col3" >0.540076</td>
#       <td id="T_8cb17_row1_col4" class="data row1 col4" >125</td>
#       <td id="T_8cb17_row1_col5" class="data row1 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row2_col0" class="data row2 col0" >0.4</td>
#       <td id="T_8cb17_row2_col1" class="data row2 col1" >0.599303</td>
#       <td id="T_8cb17_row2_col2" class="data row2 col2" >0.632867</td>
#       <td id="T_8cb17_row2_col3" class="data row2 col3" >0.602398</td>
#       <td id="T_8cb17_row2_col4" class="data row2 col4" >125</td>
#       <td id="T_8cb17_row2_col5" class="data row2 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row3_col0" class="data row3 col0" >0.45</td>
#       <td id="T_8cb17_row3_col1" class="data row3 col1" >0.601050</td>
#       <td id="T_8cb17_row3_col2" class="data row3 col2" >0.653263</td>
#       <td id="T_8cb17_row3_col3" class="data row3 col3" >0.568084</td>
#       <td id="T_8cb17_row3_col4" class="data row3 col4" >125</td>
#       <td id="T_8cb17_row3_col5" class="data row3 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row4_col0" class="data row4 col0" >0.45</td>
#       <td id="T_8cb17_row4_col1" class="data row4 col1" >0.574026</td>
#       <td id="T_8cb17_row4_col2" class="data row4 col2" >0.610723</td>
#       <td id="T_8cb17_row4_col3" class="data row4 col3" >0.552560</td>
#       <td id="T_8cb17_row4_col4" class="data row4 col4" >125</td>
#       <td id="T_8cb17_row4_col5" class="data row4 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row5_col0" class="data row5 col0" >0.45</td>
#       <td id="T_8cb17_row5_col1" class="data row5 col1" >0.613492</td>
#       <td id="T_8cb17_row5_col2" class="data row5 col2" >0.638889</td>
#       <td id="T_8cb17_row5_col3" class="data row5 col3" >0.620522</td>
#       <td id="T_8cb17_row5_col4" class="data row5 col4" >125</td>
#       <td id="T_8cb17_row5_col5" class="data row5 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row6_col0" class="data row6 col0" >0.5</td>
#       <td id="T_8cb17_row6_col1" class="data row6 col1" >0.607987</td>
#       <td id="T_8cb17_row6_col2" class="data row6 col2" >0.663364</td>
#       <td id="T_8cb17_row6_col3" class="data row6 col3" >0.581105</td>
#       <td id="T_8cb17_row6_col4" class="data row6 col4" >125</td>
#       <td id="T_8cb17_row6_col5" class="data row6 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row7_col0" class="data row7 col0" >0.5</td>
#       <td id="T_8cb17_row7_col1" class="data row7 col1" >0.577726</td>
#       <td id="T_8cb17_row7_col2" class="data row7 col2" >0.615773</td>
#       <td id="T_8cb17_row7_col3" class="data row7 col3" >0.558824</td>
#       <td id="T_8cb17_row7_col4" class="data row7 col4" >125</td>
#       <td id="T_8cb17_row7_col5" class="data row7 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row8_col0" class="data row8 col0" >0.5</td>
#       <td id="T_8cb17_row8_col1" class="data row8 col1" >0.627173</td>
#       <td id="T_8cb17_row8_col2" class="data row8 col2" >0.630730</td>
#       <td id="T_8cb17_row8_col3" class="data row8 col3" >0.628867</td>
#       <td id="T_8cb17_row8_col4" class="data row8 col4" >125</td>
#       <td id="T_8cb17_row8_col5" class="data row8 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row9_col0" class="data row9 col0" >0.55</td>
#       <td id="T_8cb17_row9_col1" class="data row9 col1" >0.595471</td>
#       <td id="T_8cb17_row9_col2" class="data row9 col2" >0.644134</td>
#       <td id="T_8cb17_row9_col3" class="data row9 col3" >0.569707</td>
#       <td id="T_8cb17_row9_col4" class="data row9 col4" >125</td>
#       <td id="T_8cb17_row9_col5" class="data row9 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row10_col0" class="data row10 col0" >0.55</td>
#       <td id="T_8cb17_row10_col1" class="data row10 col1" >0.581499</td>
#       <td id="T_8cb17_row10_col2" class="data row10 col2" >0.620824</td>
#       <td id="T_8cb17_row10_col3" class="data row10 col3" >0.565105</td>
#       <td id="T_8cb17_row10_col4" class="data row10 col4" >125</td>
#       <td id="T_8cb17_row10_col5" class="data row10 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row11_col0" class="data row11 col0" >0.55</td>
#       <td id="T_8cb17_row11_col1" class="data row11 col1" >0.629125</td>
#       <td id="T_8cb17_row11_col2" class="data row11 col2" >0.621601</td>
#       <td id="T_8cb17_row11_col3" class="data row11 col3" >0.625000</td>
#       <td id="T_8cb17_row11_col4" class="data row11 col4" >125</td>
#       <td id="T_8cb17_row11_col5" class="data row11 col5" >basic</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row12_col0" class="data row12 col0" >0.6</td>
#       <td id="T_8cb17_row12_col1" class="data row12 col1" >0.582946</td>
#       <td id="T_8cb17_row12_col2" class="data row12 col2" >0.624903</td>
#       <td id="T_8cb17_row12_col3" class="data row12 col3" >0.558113</td>
#       <td id="T_8cb17_row12_col4" class="data row12 col4" >125</td>
#       <td id="T_8cb17_row12_col5" class="data row12 col5" >word-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row13_col0" class="data row13 col0" >0.6</td>
#       <td id="T_8cb17_row13_col1" class="data row13 col1" >0.585353</td>
#       <td id="T_8cb17_row13_col2" class="data row13 col2" >0.625874</td>
#       <td id="T_8cb17_row13_col3" class="data row13 col3" >0.571407</td>
#       <td id="T_8cb17_row13_col4" class="data row13 col4" >125</td>
#       <td id="T_8cb17_row13_col5" class="data row13 col5" >sent-major-minor</td>
#     </tr>
#     <tr>
#       <td id="T_8cb17_row14_col0" class="data row14 col0" >0.6</td>
#       <td id="T_8cb17_row14_col1" class="data row14 col1" >0.609091</td>
#       <td id="T_8cb17_row14_col2" class="data row14 col2" >0.569930</td>
#       <td id="T_8cb17_row14_col3" class="data row14 col3" >0.576963</td>
#       <td id="T_8cb17_row14_col4" class="data row14 col4" >125</td>
#       <td id="T_8cb17_row14_col5" class="data row14 col5" >basic</td>
#     </tr>
#   </tbody>
# </table>

# %%
contf_mt.get_best()
# Out:
#      precision   recall  f1-score  support t_metric
# 0.5   0.627173  0.63073  0.628867    125.0    basic

# %%
best_thres_report_mt = pd.DataFrame.from_dict(contf_mt.thres_reports[contf_mt.get_best().index[0]][contf_mt.get_best().iloc[0].t_metric]).T
best_thres_report_mt.loc['accuracy', 'precision'] = None
best_thres_report_mt.loc['accuracy', 'recall'] = None
best_thres_report_mt.loc['accuracy', 'support'] = best_thres_report_mt.loc['macro avg', 'support']

# %%
best_thres_report_mt
# Out:
#                 precision    recall  f1-score  support
# creative shift   0.407407  0.423077  0.415094     26.0
# reproduction     0.846939  0.838384  0.842640     99.0
# accuracy              NaN       NaN  0.752000    125.0
# macro avg        0.627173  0.630730  0.628867    125.0
# weighted avg     0.755516  0.752000  0.753710    125.0

# %%
contf_mt.best_df().to_csv('../results/machine_context_data.tsv', sep='\t')
best_thres_report_mt.to_csv('../results/machine_context_best_thres_report.tsv', sep='\t')
context_thres_mt.to_csv('../results/machine_context_thresholds.tsv', sep='\t')
contf_mt.retrieve_best_gold().reset_index(names='orig_df_idx').to_csv('../results/machine_context_best_thres_gold.tsv', sep='\t')

# %% [markdown]
# # Syntax

# %% [markdown]
# ## Human

# %%
synt_hu = pd.read_csv('../results/syntax_data_input.tsv', sep='\t', index_col=0)
syntf = SyntaxThres()

# %%
syntf(synt_hu)

# %%
syntf.score()

# %%
synt_thres = syntf.comp_df.reset_index(names='threshold')
synt_thres.threshold = synt_thres.threshold.map(lambda x: f'{x}')
synt_thres.support = synt_thres.support.map(lambda x: int(x))
display(synt_thres.style.highlight_max(subset=['f1-score'], color = 'mediumseagreen', axis = 0).hide())
# Out:
# <style type="text/css">
# #T_cb070_row10_col3 {
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_cb070">
#   <thead>
#     <tr>
#       <th id="T_cb070_level0_col0" class="col_heading level0 col0" >threshold</th>
#       <th id="T_cb070_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_cb070_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_cb070_level0_col3" class="col_heading level0 col3" >f1-score</th>
#       <th id="T_cb070_level0_col4" class="col_heading level0 col4" >support</th>
#       <th id="T_cb070_level0_col5" class="col_heading level0 col5" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cb070_row0_col0" class="data row0 col0" >0.4</td>
#       <td id="T_cb070_row0_col1" class="data row0 col1" >0.512733</td>
#       <td id="T_cb070_row0_col2" class="data row0 col2" >0.514286</td>
#       <td id="T_cb070_row0_col3" class="data row0 col3" >0.509804</td>
#       <td id="T_cb070_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_cb070_row0_col5" class="data row0 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row1_col0" class="data row1 col0" >0.4</td>
#       <td id="T_cb070_row1_col1" class="data row1 col1" >0.604039</td>
#       <td id="T_cb070_row1_col2" class="data row1 col2" >0.621429</td>
#       <td id="T_cb070_row1_col3" class="data row1 col3" >0.600906</td>
#       <td id="T_cb070_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_cb070_row1_col5" class="data row1 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row2_col0" class="data row2 col0" >0.4</td>
#       <td id="T_cb070_row2_col1" class="data row2 col1" >0.552083</td>
#       <td id="T_cb070_row2_col2" class="data row2 col2" >0.561905</td>
#       <td id="T_cb070_row2_col3" class="data row2 col3" >0.537621</td>
#       <td id="T_cb070_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_cb070_row2_col5" class="data row2 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row3_col0" class="data row3 col0" >0.45</td>
#       <td id="T_cb070_row3_col1" class="data row3 col1" >0.512733</td>
#       <td id="T_cb070_row3_col2" class="data row3 col2" >0.514286</td>
#       <td id="T_cb070_row3_col3" class="data row3 col3" >0.509804</td>
#       <td id="T_cb070_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_cb070_row3_col5" class="data row3 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row4_col0" class="data row4 col0" >0.45</td>
#       <td id="T_cb070_row4_col1" class="data row4 col1" >0.583333</td>
#       <td id="T_cb070_row4_col2" class="data row4 col2" >0.595238</td>
#       <td id="T_cb070_row4_col3" class="data row4 col3" >0.582418</td>
#       <td id="T_cb070_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_cb070_row4_col5" class="data row4 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row5_col0" class="data row5 col0" >0.45</td>
#       <td id="T_cb070_row5_col1" class="data row5 col1" >0.536526</td>
#       <td id="T_cb070_row5_col2" class="data row5 col2" >0.542857</td>
#       <td id="T_cb070_row5_col3" class="data row5 col3" >0.528100</td>
#       <td id="T_cb070_row5_col4" class="data row5 col4" >100</td>
#       <td id="T_cb070_row5_col5" class="data row5 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row6_col0" class="data row6 col0" >0.5</td>
#       <td id="T_cb070_row6_col1" class="data row6 col1" >0.512733</td>
#       <td id="T_cb070_row6_col2" class="data row6 col2" >0.514286</td>
#       <td id="T_cb070_row6_col3" class="data row6 col3" >0.509804</td>
#       <td id="T_cb070_row6_col4" class="data row6 col4" >100</td>
#       <td id="T_cb070_row6_col5" class="data row6 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row7_col0" class="data row7 col0" >0.5</td>
#       <td id="T_cb070_row7_col1" class="data row7 col1" >0.643986</td>
#       <td id="T_cb070_row7_col2" class="data row7 col2" >0.621429</td>
#       <td id="T_cb070_row7_col3" class="data row7 col3" >0.627776</td>
#       <td id="T_cb070_row7_col4" class="data row7 col4" >100</td>
#       <td id="T_cb070_row7_col5" class="data row7 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row8_col0" class="data row8 col0" >0.5</td>
#       <td id="T_cb070_row8_col1" class="data row8 col1" >0.591146</td>
#       <td id="T_cb070_row8_col2" class="data row8 col2" >0.600000</td>
#       <td id="T_cb070_row8_col3" class="data row8 col3" >0.592944</td>
#       <td id="T_cb070_row8_col4" class="data row8 col4" >100</td>
#       <td id="T_cb070_row8_col5" class="data row8 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row9_col0" class="data row9 col0" >0.55</td>
#       <td id="T_cb070_row9_col1" class="data row9 col1" >0.519305</td>
#       <td id="T_cb070_row9_col2" class="data row9 col2" >0.521429</td>
#       <td id="T_cb070_row9_col3" class="data row9 col3" >0.517450</td>
#       <td id="T_cb070_row9_col4" class="data row9 col4" >100</td>
#       <td id="T_cb070_row9_col5" class="data row9 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row10_col0" class="data row10 col0" >0.55</td>
#       <td id="T_cb070_row10_col1" class="data row10 col1" >0.657343</td>
#       <td id="T_cb070_row10_col2" class="data row10 col2" >0.628571</td>
#       <td id="T_cb070_row10_col3" class="data row10 col3" >0.636175</td>
#       <td id="T_cb070_row10_col4" class="data row10 col4" >100</td>
#       <td id="T_cb070_row10_col5" class="data row10 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row11_col0" class="data row11 col0" >0.55</td>
#       <td id="T_cb070_row11_col1" class="data row11 col1" >0.592718</td>
#       <td id="T_cb070_row11_col2" class="data row11 col2" >0.597619</td>
#       <td id="T_cb070_row11_col3" class="data row11 col3" >0.594485</td>
#       <td id="T_cb070_row11_col4" class="data row11 col4" >100</td>
#       <td id="T_cb070_row11_col5" class="data row11 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row12_col0" class="data row12 col0" >0.6</td>
#       <td id="T_cb070_row12_col1" class="data row12 col1" >0.519305</td>
#       <td id="T_cb070_row12_col2" class="data row12 col2" >0.521429</td>
#       <td id="T_cb070_row12_col3" class="data row12 col3" >0.517450</td>
#       <td id="T_cb070_row12_col4" class="data row12 col4" >100</td>
#       <td id="T_cb070_row12_col5" class="data row12 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row13_col0" class="data row13 col0" >0.6</td>
#       <td id="T_cb070_row13_col1" class="data row13 col1" >0.666667</td>
#       <td id="T_cb070_row13_col2" class="data row13 col2" >0.571429</td>
#       <td id="T_cb070_row13_col3" class="data row13 col3" >0.562500</td>
#       <td id="T_cb070_row13_col4" class="data row13 col4" >100</td>
#       <td id="T_cb070_row13_col5" class="data row13 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_cb070_row14_col0" class="data row14 col0" >0.6</td>
#       <td id="T_cb070_row14_col1" class="data row14 col1" >0.522831</td>
#       <td id="T_cb070_row14_col2" class="data row14 col2" >0.521429</td>
#       <td id="T_cb070_row14_col3" class="data row14 col3" >0.521531</td>
#       <td id="T_cb070_row14_col4" class="data row14 col4" >100</td>
#       <td id="T_cb070_row14_col5" class="data row14 col5" >astred_label</td>
#     </tr>
#   </tbody>
# </table>

# %%
syntf.get_best()
# Out:
#       precision    recall  f1-score  support     t_metric
# 0.55   0.657343  0.628571  0.636175    100.0  label_label

# %%
best_thres_report = pd.DataFrame.from_dict(syntf.thres_reports[syntf.get_best().index[0]][syntf.get_best().iloc[0].t_metric]).T
best_thres_report.loc['accuracy', 'precision'] = None
best_thres_report.loc['accuracy', 'recall'] = None
best_thres_report.loc['accuracy', 'support'] = best_thres_report.loc['macro avg', 'support']

# %%
best_thres_report
# Out:
#                 precision    recall  f1-score  support
# creative shift   0.545455  0.400000  0.461538     30.0
# reproduction     0.769231  0.857143  0.810811     70.0
# accuracy              NaN       NaN  0.720000    100.0
# macro avg        0.657343  0.628571  0.636175    100.0
# weighted avg     0.702098  0.720000  0.706029    100.0

# %%
syntf.best_df().to_csv('../results/syntax_data.tsv', sep='\t')
best_thres_report.to_csv('../results/syntax_best_thres_report.tsv', sep='\t')
synt_thres.to_csv('../results/syntax_thresholds.tsv', sep='\t')

# %% [markdown]
# ## Machine

# %%
synt_mt = pd.read_csv('../results/machine_syntax_data_input.tsv', sep='\t', index_col=0)
syntf_mt = SyntaxThres()

# %%
syntf_mt(synt_mt)

# %%
syntf_mt.score()

# %%
synt_thres_mt = syntf_mt.comp_df.reset_index(names='threshold')
synt_thres_mt.threshold = synt_thres_mt.threshold.map(lambda x: f'{x}')
synt_thres_mt.support = synt_thres_mt.support.map(lambda x: int(x))
display(synt_thres_mt.style.highlight_max(subset=['f1-score'], color = 'mediumseagreen', axis = 0).hide())
# Out:
# <style type="text/css">
# #T_6f3f8_row13_col3 {
#   background-color: mediumseagreen;
# }
# </style>
# <table id="T_6f3f8">
#   <thead>
#     <tr>
#       <th id="T_6f3f8_level0_col0" class="col_heading level0 col0" >threshold</th>
#       <th id="T_6f3f8_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_6f3f8_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_6f3f8_level0_col3" class="col_heading level0 col3" >f1-score</th>
#       <th id="T_6f3f8_level0_col4" class="col_heading level0 col4" >support</th>
#       <th id="T_6f3f8_level0_col5" class="col_heading level0 col5" >t_metric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6f3f8_row0_col0" class="data row0 col0" >0.4</td>
#       <td id="T_6f3f8_row0_col1" class="data row0 col1" >0.512627</td>
#       <td id="T_6f3f8_row0_col2" class="data row0 col2" >0.524621</td>
#       <td id="T_6f3f8_row0_col3" class="data row0 col3" >0.493787</td>
#       <td id="T_6f3f8_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_6f3f8_row0_col5" class="data row0 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row1_col0" class="data row1 col0" >0.4</td>
#       <td id="T_6f3f8_row1_col1" class="data row1 col1" >0.520499</td>
#       <td id="T_6f3f8_row1_col2" class="data row1 col2" >0.543561</td>
#       <td id="T_6f3f8_row1_col3" class="data row1 col3" >0.491813</td>
#       <td id="T_6f3f8_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_6f3f8_row1_col5" class="data row1 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row2_col0" class="data row2 col0" >0.4</td>
#       <td id="T_6f3f8_row2_col1" class="data row2 col1" >0.565062</td>
#       <td id="T_6f3f8_row2_col2" class="data row2 col2" >0.638258</td>
#       <td id="T_6f3f8_row2_col3" class="data row2 col3" >0.548278</td>
#       <td id="T_6f3f8_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_6f3f8_row2_col5" class="data row2 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row3_col0" class="data row3 col0" >0.45</td>
#       <td id="T_6f3f8_row3_col1" class="data row3 col1" >0.512627</td>
#       <td id="T_6f3f8_row3_col2" class="data row3 col2" >0.524621</td>
#       <td id="T_6f3f8_row3_col3" class="data row3 col3" >0.493787</td>
#       <td id="T_6f3f8_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_6f3f8_row3_col5" class="data row3 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row4_col0" class="data row4 col0" >0.45</td>
#       <td id="T_6f3f8_row4_col1" class="data row4 col1" >0.544647</td>
#       <td id="T_6f3f8_row4_col2" class="data row4 col2" >0.583333</td>
#       <td id="T_6f3f8_row4_col3" class="data row4 col3" >0.538143</td>
#       <td id="T_6f3f8_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_6f3f8_row4_col5" class="data row4 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row5_col0" class="data row5 col0" >0.45</td>
#       <td id="T_6f3f8_row5_col1" class="data row5 col1" >0.572610</td>
#       <td id="T_6f3f8_row5_col2" class="data row5 col2" >0.649621</td>
#       <td id="T_6f3f8_row5_col3" class="data row5 col3" >0.562937</td>
#       <td id="T_6f3f8_row5_col4" class="data row5 col4" >100</td>
#       <td id="T_6f3f8_row5_col5" class="data row5 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row6_col0" class="data row6 col0" >0.5</td>
#       <td id="T_6f3f8_row6_col1" class="data row6 col1" >0.512627</td>
#       <td id="T_6f3f8_row6_col2" class="data row6 col2" >0.524621</td>
#       <td id="T_6f3f8_row6_col3" class="data row6 col3" >0.493787</td>
#       <td id="T_6f3f8_row6_col4" class="data row6 col4" >100</td>
#       <td id="T_6f3f8_row6_col5" class="data row6 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row7_col0" class="data row7 col0" >0.5</td>
#       <td id="T_6f3f8_row7_col1" class="data row7 col1" >0.607869</td>
#       <td id="T_6f3f8_row7_col2" class="data row7 col2" >0.615530</td>
#       <td id="T_6f3f8_row7_col3" class="data row7 col3" >0.611429</td>
#       <td id="T_6f3f8_row7_col4" class="data row7 col4" >100</td>
#       <td id="T_6f3f8_row7_col5" class="data row7 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row8_col0" class="data row8 col0" >0.5</td>
#       <td id="T_6f3f8_row8_col1" class="data row8 col1" >0.585478</td>
#       <td id="T_6f3f8_row8_col2" class="data row8 col2" >0.666667</td>
#       <td id="T_6f3f8_row8_col3" class="data row8 col3" >0.585826</td>
#       <td id="T_6f3f8_row8_col4" class="data row8 col4" >100</td>
#       <td id="T_6f3f8_row8_col5" class="data row8 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row9_col0" class="data row9 col0" >0.55</td>
#       <td id="T_6f3f8_row9_col1" class="data row9 col1" >0.512627</td>
#       <td id="T_6f3f8_row9_col2" class="data row9 col2" >0.524621</td>
#       <td id="T_6f3f8_row9_col3" class="data row9 col3" >0.493787</td>
#       <td id="T_6f3f8_row9_col4" class="data row9 col4" >100</td>
#       <td id="T_6f3f8_row9_col5" class="data row9 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row10_col0" class="data row10 col0" >0.55</td>
#       <td id="T_6f3f8_row10_col1" class="data row10 col1" >0.621212</td>
#       <td id="T_6f3f8_row10_col2" class="data row10 col2" >0.621212</td>
#       <td id="T_6f3f8_row10_col3" class="data row10 col3" >0.621212</td>
#       <td id="T_6f3f8_row10_col4" class="data row10 col4" >100</td>
#       <td id="T_6f3f8_row10_col5" class="data row10 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row11_col0" class="data row11 col0" >0.55</td>
#       <td id="T_6f3f8_row11_col1" class="data row11 col1" >0.595383</td>
#       <td id="T_6f3f8_row11_col2" class="data row11 col2" >0.678030</td>
#       <td id="T_6f3f8_row11_col3" class="data row11 col3" >0.601847</td>
#       <td id="T_6f3f8_row11_col4" class="data row11 col4" >100</td>
#       <td id="T_6f3f8_row11_col5" class="data row11 col5" >astred_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row12_col0" class="data row12 col0" >0.6</td>
#       <td id="T_6f3f8_row12_col1" class="data row12 col1" >0.512627</td>
#       <td id="T_6f3f8_row12_col2" class="data row12 col2" >0.524621</td>
#       <td id="T_6f3f8_row12_col3" class="data row12 col3" >0.493787</td>
#       <td id="T_6f3f8_row12_col4" class="data row12 col4" >100</td>
#       <td id="T_6f3f8_row12_col5" class="data row12 col5" >sacr_cross_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row13_col0" class="data row13 col0" >0.6</td>
#       <td id="T_6f3f8_row13_col1" class="data row13 col1" >0.752632</td>
#       <td id="T_6f3f8_row13_col2" class="data row13 col2" >0.613636</td>
#       <td id="T_6f3f8_row13_col3" class="data row13 col3" >0.646416</td>
#       <td id="T_6f3f8_row13_col4" class="data row13 col4" >100</td>
#       <td id="T_6f3f8_row13_col5" class="data row13 col5" >label_label</td>
#     </tr>
#     <tr>
#       <td id="T_6f3f8_row14_col0" class="data row14 col0" >0.6</td>
#       <td id="T_6f3f8_row14_col1" class="data row14 col1" >0.597902</td>
#       <td id="T_6f3f8_row14_col2" class="data row14 col2" >0.659091</td>
#       <td id="T_6f3f8_row14_col3" class="data row14 col3" >0.610206</td>
#       <td id="T_6f3f8_row14_col4" class="data row14 col4" >100</td>
#       <td id="T_6f3f8_row14_col5" class="data row14 col5" >astred_label</td>
#     </tr>
#   </tbody>
# </table>

# %%
syntf_mt.get_best()
# Out:
#      precision    recall  f1-score  support     t_metric
# 0.6   0.752632  0.613636  0.646416    100.0  label_label

# %%
best_thres_report_mt = pd.DataFrame.from_dict(syntf_mt.thres_reports[syntf_mt.get_best().index[0]][syntf_mt.get_best().iloc[0].t_metric]).T
best_thres_report_mt.loc['accuracy', 'precision'] = None
best_thres_report_mt.loc['accuracy', 'recall'] = None
best_thres_report_mt.loc['accuracy', 'support'] = best_thres_report_mt.loc['macro avg', 'support']

# %%
best_thres_report_mt
# Out:
#                 precision    recall  f1-score  support
# creative shift   0.600000  0.250000  0.352941     12.0
# reproduction     0.905263  0.977273  0.939891     88.0
# accuracy              NaN       NaN  0.890000    100.0
# macro avg        0.752632  0.613636  0.646416    100.0
# weighted avg     0.868632  0.890000  0.869457    100.0

# %%
syntf_mt.best_df().to_csv('../results/machine_syntax_data.tsv', sep='\t')
best_thres_report_mt.to_csv('../results/machine_syntax_best_thres_report.tsv', sep='\t')
synt_thres_mt.to_csv('../results/machine_syntax_thresholds.tsv', sep='\t')
